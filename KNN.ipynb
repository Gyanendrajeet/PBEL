# %% [markdown]
# # K-Nearest Neighbors

# %% [markdown]
# 1. You move to a new city and want to decide wheather a restaurant is good ?
# 2. How ?
# 3. Check reviews
# 4. Ask nearby prople
# 5. See what friend recommendation
# 6. KNN also aks its nearest neighbors before making a prediction.

# %% [markdown]
# 2. K-Nearest neighbors (KNN) is a supervised machine learning algorithm
# - Used for :
#         - Classification
#         - Regression
# - It predict the output by looking at the K nearest data points.
#
# - **Example**:
#      - A new student Join a Class.
#         - Nearby Student :
#             - A -> Science
#             - B -> Science
#             - C -> Commerce
#     - Predict -> Science
#
# - **Example**:
#      - Movie Recommendation:
#               - Himank -> Action
#               - Mihika -> Thriller
#               - Shaurya -> Action
#               - Saurabh -> Action
#               - Predict -> Action

# %% [markdown]
# # Where KNN is Used

# %% [markdown]
# - Email Spam Detection
# - Disease Prediction
# - Student will pass or not
# - Banking (credit approval)
# - Face recognition

# %% [markdown]
# # Types of Problems solved

# %% [markdown]
# - 1. Classification :
#   - output is category
#   - ex - >>> spam or not spam
#   - Disease or not (cancer)
#   - male or female
#
# - 2. Regression:
#   - Output is continuous value
#   - Ex -> House price
#   - Salary prediction
#   - temperature predict
#
# - 3. why ???
#   - Suppose there is a new point
#   - There are many old data point
#   - The closed one
#   - Because nearby objects usually have similar properties.
#
# - 4. Distance Measure.....!!!!
#   - Eucludiean
#   - d = sqrt((x2-x1)^2 + (y2-y1)^2)
#   - point A - (2,3)
#   - point B - (5,7)
#   - Distance = sqrt((5-2)^2 + (7-3)^2) = 9 + 16 = 25 =>5
#
#
# - 5. Manhattan Distance
#   - Like walking on roads
#   - Can not move diagonally
#   - From = |x2-x1|+|y2-y1|
#
#
# - 6. Hamming Distance
#   - Used for CAtegorical Data
#   - Binary Data
#   - Ex: 101110 ->> 10011
#   - Different bits = Hamming distance

# %% [markdown]
# 3. K means Number of nearest neighbors
#    - K = 3 : Look at nearest 3 neighbors
#    - K = 5 : Then look at nearest 5 neighbours
# - Example:
#      - Suppose : red, red, blue, k =3
#      - Majority: Red
#      - predict: red

# %% [markdown]
# 4. Choosing K?
#   - Smakk k :
#   - Advantage : sensitive, captures local pattern
#   - disadvantage : Overfitting, Noise affect prediction

# %% [markdown]
# - Large K:
#     - advantage: Stable, Less noise
#     - disadvantage : Underfitting

# %% [markdown]
# # Important:
# - Golden Rules
#     - k = underroot (N)
#     - N: Number of samples
#     - Example: 100 samples = √N = √100 = 10
#     - K = 10, then use cross validation to choose the best k

# %% [markdown]
# # Working

# %% [markdown]
# 1. Choosing k
# 2. Calculate Distance
# 3. Find K nearest Neighbors
# 4. voting
# 5. predict our class

# %% [markdown]
# - Suppose k =3
# - Neighbor: A
# - Neighbor: B
# - Neighbor: A
# - Neighbor: C
# - predict: A

# %% [markdown]
# 2. Neighbors: Cat
#
# - Neighbors: Dog
# - Neighbors: Dog
# - predict: Dog

# %% [markdown]
# # Dataset

# %% [markdown]
# - height: 160,165,170,180,185
# - weight: 55,60,65,90,95
# - class:fit,fit,fit,unfit,unfit

# %% [markdown]
# - New person:
# - height is 172
# - weight 68
# - Class? Fit or Unfit?
#
#
#
#   - Predict: Fit

# %% [markdown]
# # Feature Scalling ?

# %% [markdown]
# - Age : 20
# - Salary: 800000
# - Which feature dominates
# - Salary
# - Therefore always scale data before KNN

# %% [markdown]
# #### KNN Lazy learner or Fast learner ? and why ?

# %% [markdown]
# -- Lazy learner

# %% [markdown]
# - Because it does not learn during training
# - It stores data and predicts only when a new sampe arrives

# %% [markdown]
# # KNN
# - Lazy learner, It does not require training, and it works on distance based so slow prediction.
# # Logistic Regression:
# - Eafer learner, It require a training and it is based on probability and fast doing fast prediction

# %% [markdown]
# # Practicle:

# %% [markdown]
# #### Import libraries
# #### Load dataset
# #### Explore dataset
# #### Separete feature and target
# #### Train_test_split
# #### feature scaling
# #### create model
# #### train model
# #### predict through our test data
# #### evaluate model (accuracy, precision, recall, classification report)
# #### new sample predict
# #### find best k value

# %%
import numpy as numpy # nuerical operations 
import pandas as pd # Data manipulation
import matplotlib.pyplot as plt # visualization plloting 
import seaborn as sns # visualization

# %%
from sklearn.datasets import load_breast_cancer 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score,recall_score,f1_score

# %%
cancer = load_breast_cancer()

# %%
df = pd.DataFrame(
    cancer.data,
    columns=cancer.feature_names
)

# %%
df['Target'] = cancer.target

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  Target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
print("shape:", df.shape)
# Out:
# shape: (569, 31)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  Target                   569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB
# None

# %%
print(df.isnull().sum())
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# Target                     0
# dtype: int64

# %%
print(df['Target'].value_counts())
# Out:
# Target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
X = df.drop('Target', axis=1) # Independent variable
y = df['Target'] # Dependent variable

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y,test_size=0.25,random_state = 40, stratify=y
)

# %%
X_train.shape
# Out:
# (426, 30)

# %%
X_test.shape
# Out:
# (143, 30)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn
# Out:
# KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
pred = knn.predict(X_test)

# %%
comparison = pd.DataFrame({
    "Actual": y_test.values,
    'Predicted': pred
})

# %%
accuracy = accuracy_score(y_test,pred)
accuracy
# Out:
# 0.9440559440559441

# %%
precision = precision_score(y_test,pred) # correct positive prediction
precision
# Out:
# 0.9659090909090909

# %%
recall = recall_score(y_test,pred) # Actual positive correctly identified 
recall
# Out:
# 0.9444444444444444

# %%
f1 = f1_score(y_test,pred) # Balance btw precision and recall
f1
# Out:
# 0.9550561797752809

# %%
cm = confusion_matrix(y_test,pred)
print(cm)
# Out:
# [[50  3]
#  [ 5 85]]

# %%
plt.figure(figsize=(8,5))

sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=['Malignant', 'Benign'], yticklabels=['Malignant', 'Benign'])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93        53
#            1       0.97      0.94      0.96        90
#
#     accuracy                           0.94       143
#    macro avg       0.94      0.94      0.94       143
# weighted avg       0.94      0.94      0.94       143

# %%
sample = X.iloc[[0]]
sam = scaler.transform(sample)
prediction = knn.predict(sam)

print("Predicted Class:", prediction[0])
print("Actual Class:", y.iloc[0])
# Out:
# Predicted Class: 1
# Actual Class: 0
# c:\Users\Gyanendra Shukla\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
acc_score = []
for k in range(1,8):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train,y_train)
    prediction = model.predict(X_test)
    score = accuracy_score(y_test,prediction)
    acc_score.append(score)

plt.figure(figsize=(8,5))
plt.plot(range(1,8),acc_score,marker='o' )
plt.xlabel("K value")
plt.ylabel("Accuracy")
plt.title("Choosing the best K")
plt.show()

# %%
acc_score = []
for k in range(1,20):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train,y_train)
    prediction = model.predict(X_test)
    score = accuracy_score(y_test,prediction)
    acc_score.append(score)

plt.figure(figsize=(8,5))
plt.plot(range(1,20),acc_score,marker='o' )
plt.xlabel("K value")
plt.ylabel("Accuracy")
plt.title("Choosing the best K")
plt.show()

# %% [markdown]
# # Practical

# %% [markdown]
# #### Dataset : iris

# %%
from sklearn.datasets import load_iris

iris = load_iris()

# %%
df2 = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

# %%
df2["target"] = iris.target

# %%
df2.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print("shape:", df2.shape)
# Out:
# shape: (150, 5)

# %%
print(df2.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None

# %%
print(df2.isnull().sum())
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
print(df2['target'].value_counts())
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
X = df2.drop('target', axis=1) # Independent variable
y = df2['target'] # Dependent variable

# %%
print(df2['target'].value_counts())
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
X_tr, X_ts, y_tr, y_ts = train_test_split(
    X,y,test_size=0.25,random_state = 40, stratify=y
)

# %%
X_tr.shape
# Out:
# (112, 4)

# %%
X_ts.shape
# Out:
# (38, 4)

# %%
scaler = StandardScaler()

X_tr = scaler.fit_transform(X_tr)
X_ts = scaler.transform(X_ts)

# %%
knn = KNeighborsClassifier(n_neighbors=7)
knn
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X_tr, y_tr)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
pre = knn.predict(X_ts)

# %%
comparison = pd.DataFrame({
    "Actual": y_ts.values,
    "Predicted": pre
})

# %%
accuracy = accuracy_score(y_ts,pre)
accuracy
# Out:
# 0.9736842105263158

# %%
cm2 = confusion_matrix(y_ts,pre)
print(cm2)
# Out:
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  1 12]]

# %%
plt.figure(figsize=(8,5))

sns.heatmap(cm2, annot=True, fmt="d", cmap='Blues', xticklabels=['Malignant', 'Benign'], yticklabels=['Malignant', 'Benign'])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(y_ts,pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       0.93      1.00      0.96        13
#            2       1.00      0.92      0.96        13
#
#     accuracy                           0.97        38
#    macro avg       0.98      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %%
sample = X.iloc[[0]]
sam = scaler.transform(sample)
predict = knn.predict(sam)

print("Predicted Class:", prediction[0])
print("Actual Class:", y.iloc[0])
# Out:
# Predicted Class: 0
# Actual Class: 0

# %%
acc_score = []
for k in range(1,16):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_tr,y_tr)
    predict = model.predict(X_ts)
    score = accuracy_score(y_ts,predict)
    acc_score.append(score)

plt.figure(figsize=(8,5))
plt.plot(range(1,16),acc_score,marker='o' )
plt.xlabel("K value")
plt.ylabel("Accuracy")
plt.title("Choosing the best K")
plt.show()
