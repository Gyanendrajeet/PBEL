# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('Mine/tipsdataset.csv')

# %%
# univarite
plt.plot(df['total_bill'])
plt.xlabel("EXAMPLE")
plt.show()
